# %% [markdown]
# EX2: Given the dataset of human’s weight and height, write a Python program to estimate the weight given the height, e.g.155 and 160 (cm)?

# %% [markdown]
# dataset:
# Height(cm): 147 150 153 155 158 160 163 165 168 170 173 175 178 180 183
# Weight(kg): 49  50  51  52  54  56  58  59  60  62  63  64  66  67  68

# %%
# import important libraries 
import numpy as np
import matplotlib.pyplot as plt

# %%
# height (cm)
X = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
# weight (kg)
y = np.array([[ 49, 50, 51,  54, 58, 59, 60, 62, 63, 64, 66, 67, 68]]).T
# Visualize data
plt.plot(X, y, 'ro')
plt.axis([140, 190, 45, 75])
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
# Building Xbar 
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1)

# Calculating weights of the fitting line 
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)
print('w = ', w)

# Preparing the fitting line 
w_0 = w[0][0]
w_1 = w[1][0]
x0 = np.linspace(145, 185, 2)
y0 = w_0 + w_1*x0

# Drawing the fitting line 
plt.plot(X.T, y.T, 'ro')     # data 
plt.plot(x0, y0)               # the fitting line
plt.axis([140, 190, 45, 75])
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()
# Out:
# w =  [[-33.73541021]
#  [  0.55920496]]

# %%
y1 = w_1*155 + w_0
y2 = w_1*160 + w_0

print( u'Predict weight of person with height 155 (cm): %.2f (kg), real number: 52 (kg)' %(y1) )
print( u'Predict weight of person with height 160 (cm): %.2f (kg), real number: 56 (kg)' %(y2) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 y1 = w_1*155 + w_0
#       2 y2 = w_1*160 + w_0
#       3
# ----> 4 print( u'Predict weight of person with height %d (cm): %.2f (kg), real number: 52 (kg)' %(y1) )
#       5 print( u'Predict weight of person with height %d (cm): %.2f (kg), real number: 56 (kg)' %(y2) )
#
# TypeError: not enough arguments for format string
