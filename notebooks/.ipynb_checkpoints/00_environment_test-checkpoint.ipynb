# %% [markdown]
# TEST ENVIRONMENT

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import scipy
import sklearn

print(sys.version)
print(sys.executable)
# Out:
# 3.12.13 (main, May 10 2026, 19:30:01) [Clang 22.1.3 ]
# /home/razer_admin/workspace/ML/.venv/bin/python

# %%
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("SciPy:", scipy.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1
# SciPy: 1.18.0
# Scikit-learn: 1.9.0
